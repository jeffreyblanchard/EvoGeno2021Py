# %%
DNA1 = '...'
DNA2 = '...'
DNA3 = '...'
DNA4 = '...'
DNA5 = '...'
DNA6 = '...'

length = len(DNA1)
count = 0
PATTERN = ''
while count < length :
    if DNA1[count] != DNA2[count] or DNA1[count] != DNA3[count] or DNA1[count] != DNA4[count] or DNA1[count] != DNA5[count] or DNA1[count] != DNA6[count]  :
        PATTERN = PATTERN + '*'
    else :
        PATTERN = PATTERN + '.'
    count = count + 1
# a loop to see at what position each polymorphism is
for initial_codon in range(0,3):
    nucleotides = ''
    y = initial_codon
    while y < len(PATTERN):
        nucleotides = nucleotides + PATTERN[y]
        y += 3
    print ('The polymorphisms in codon position %s are %s\n' % (initial_codon, nucleotides))
# Out:
# The polymorphisms in codon position 0 are .................**...............*..*...........*..................*...*.....*....*...........................*...................................................*....................*................................*..............................................*......*...............................................................................*.......................................*..................*.......................*....**.**
#
# The polymorphisms in codon position 1 are .....*...**......*.......*...........................................................*....................*....*........................................................................*..............................*................................................................................................................................................................................................................................*...
#
# ...
